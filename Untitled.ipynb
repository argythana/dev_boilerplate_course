# %%
from r4m import plot_daily_dashboard, activities_datafile

if __name__ == "__main__":
    # datafile = "./data/run4moreProd.activities.csv"
    plot_daily_dashboard(activities_datafile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from r4m import plot_daily_dashboard, activities_datafile
#       3 if __name__ == "__main__":
#       4     # datafile = "./data/run4moreProd.activities.csv"
#       5     plot_daily_dashboard(activities_datafile)
#
# File ~\dev_boilerplate_course\dev_boilerplate_course\r4m.py:274
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 11,
#       6    "id": "95b10c83-039d-43f4-ac8f-aac5642d7ad4",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import pandas as pd\n",
#      11     "import streamlit as st\n",
#      12     "from typing import Any\n",
#      13     "import plotly as plo"
#      14    ]
#      15   },
#      16   {
#      17    "cell_type": "code",
# ...
